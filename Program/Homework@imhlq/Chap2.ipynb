# %%
import numpy as np

# %% [markdown]
# # 1.Divide

# %% [markdown]
# Result = C(500, 350) * C(500, 350)

# %%
c350 = np.math.factorial(500) // (np.math.factorial(150) * np.math.factorial(350))
print('Result:%e' % c350**2)
# Out:
# Result:2.985945e+262

# %% [markdown]
# # 2. Major-Error

# %% [markdown]
# ## 10-fold cross
#  Trainset 45:45->random->error:50%
#
# ## Leave one out
#  Trainset 49:50->the most one->different from the leave one->error:100%

# %% [markdown]
# # 3. BEP vs F1

# %% [markdown]
# If Harmonic mean(F1) higher
#
# BEP have no decision.
# For PR-curve is highly random.

# %% [markdown]
# # 4. TPR

# %% [markdown]
# TPR=TP/(TP+FN) == R
#
# FPR=FP/(TN+FP)
#
# P = TP/(TP+FP)

# %% [markdown]
# # 5. AUC

# %% [markdown]
# ?

# %% [markdown]
# # 6.ROC and Error
# 错误率越高，roc下面积越小

# %% [markdown]
# # 7.lost curve
#
# Every point on ROC have one lost corresponding curve point.
#
# vice versa...

# %% [markdown]
# # 8. 规范化

# %% [markdown]
# # 9. $\chi^2$

# %% [markdown]
# 1. 作出 联列表
# 2. 作出假设
# 3. 计算$\chi^2$变量
# 4. 比较临界值
# 5. 给出结论

# %% [markdown]
# # 10. Friedman

# %% [markdown]
# 前者$\tau_{\chi^2}$服从$\chi^2$分布
#
# 后者$\tau_F$服从$F$分布

# %%
import matplotlib.pyplot as plt

# %%
tauX = np.arange(0, 10, 0.1)
N = 100
plt.figure(figsize=(12,8))
for k in range(2, 6):
    tauF = (N-1)*tauX / (N*(k-1) - tauX)
    plt.plot(tauX, tauF, label='k=%d' % k)
plt.legend()
plt.xlabel(r'$\tau_\chi$')
plt.ylabel(r'$\tau_F$')
# Out:
# Text(0, 0.5, '$\\tau_F$')
